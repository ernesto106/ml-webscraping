# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://github.com/ernesto106/ml-webscraping/blob/main/Employment-indicators-weekly-paid-jobs-6-20-34-days-as-at-15-November-2021-CSV.csv"
df = pd.read_csv(url)
df = df[["Value"]]
df.plot()
# Out:
# <AxesSubplot:>
